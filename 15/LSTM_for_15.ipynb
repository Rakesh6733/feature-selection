# %%
import pandas as pd

# %%
from keras.models import Sequential
from keras.layers import LSTM,Dense,Dropout

# %%
model = Sequential()
model.add(LSTM(units=50,return_sequences=True,input_shape=(15, 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=7))

# %%
model.compile(optimizer="adam",loss="mean_squared_error",metrics=['accuracy'])

# %%
mob_hist = model.fit(x_train_f,y_train_f,validation_split=0.2,epochs=5, batch_size = 64)

# %%
r = model.predict(x_test_f)

# %%
r  = np.argmax(r, axis=1)

# %%
from sklearn.metrics import confusion_matrix

# assume y_true and y_pred are the true and predicted labels, respectively
cm = confusion_matrix(y_test_f, r)

# calculate the number of false alarms
num_false_alarms = 0
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        if i != j:
            num_false_alarms += cm[i][j]

# calculate the total number of predictions
num_predictions = sum(sum(cm))

# calculate the false alarm rate
false_alarm_rate = num_false_alarms / num_predictions

print("False alarm rate: {:.9f}".format(false_alarm_rate))
