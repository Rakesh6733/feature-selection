# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df1 = pd.read_csv("/content/drive/MyDrive/data.csv")

# %%
import numpy as np

# %%
df1.replace([np.inf, -np.inf], np.nan, inplace=True)

# Dropping all the rows with nan values
df1.dropna(inplace=True)
df1.isin([np.inf, -np.inf]).sum()
data=df1

# %%
d_1 = df1.iloc[:,0]
d_4 = df1.iloc[:,1]
d_6 = df1.iloc[:,3]
d_70 = df1.iloc[:,14]
d_72 = df1.iloc[:,15]
d_73 = df1.iloc[:,18]
d_48 = df1.iloc[:,21]
d_69 = df1.iloc[:,28]
d_8 = df1.iloc[:,37]
d_30 = df1.iloc[:,47]
d_76 = df1.iloc[:,53]
d_12 = df1.iloc[:,5]
d_25 = df1.iloc[:,67]
d_65 = df1.iloc[:,68]

# %%
d78 = df1.iloc[:,-1]

# %%
dfea =pd.DataFrame([d_1,d_4,d_6,d_70,d_72,d_73,d_48,d_69,d_8,d_30,d_76,d_12,d_25,d_65,d78])

# %%
network_data=dfea.T

# %%
clean_data = network_data.dropna()

# %%
clean_data.reset_index(inplace=True, drop=True)

# %%
from sklearn.preprocessing import LabelEncoder
l = LabelEncoder()
u = l.fit_transform(clean_data.iloc[:,-1])

# %%
import numpy as np
data_1 = u[u == 0]
data_2 = u[u == 1]
data_3 = u[u == 2]
data_4 = u[u == 3]
data_5 = u[u == 4]
data_6 = u[u == 5]
data_7 = u[u == 6]


# make benign feature
y_1 = np.zeros(data_1.shape[0])
y_benign = pd.DataFrame(y_1)

# make bruteforce feature
y_2 = np.ones(data_2.shape[0])
y_bf = pd.DataFrame(y_2)

# make bruteforceSSH feature
y_3 = np.full(data_3.shape[0], 2)
y_ssh = pd.DataFrame(y_3)

y_4 = np.full(data_4.shape[0], 2)
y_ssh1 = pd.DataFrame(y_4)

y_5 = np.full(data_5.shape[0], 2)
y_ssh2 = pd.DataFrame(y_5)

y_6 = np.full(data_6.shape[0], 2)
y_ssh3 = pd.DataFrame(y_6)

y_7 = np.full(data_7.shape[0], 2)
y_ssh4 = pd.DataFrame(y_7)


# merging the original dataframe
y = pd.concat([y_benign, y_bf, y_ssh,y_ssh1,y_ssh2,y_ssh3,y_ssh4], sort=True).reset_index(drop=True)

# %%
y = u/6.0
x = clean_data.iloc[:,:-1]

# %%
from keras.utils.np_utils import to_categorical

y = to_categorical(y,num_classes=7)

# %%
clean_data.reset_index(inplace=True, drop=True)

# %%
from sklearn.preprocessing import LabelEncoder
l = LabelEncoder()
u = l.fit_transform(clean_data.iloc[:,-1])

# %%
import numpy as np
data_1 = u[u == 0]
data_2 = u[u == 1]
data_3 = u[u == 2]
data_4 = u[u == 3]
data_5 = u[u == 4]
data_6 = u[u == 5]
data_7 = u[u == 6]


# make benign feature
y_1 = np.zeros(data_1.shape[0])
y_benign = pd.DataFrame(y_1)

# make bruteforce feature
y_2 = np.ones(data_2.shape[0])
y_bf = pd.DataFrame(y_2)

# make bruteforceSSH feature
y_3 = np.full(data_3.shape[0], 2)
y_ssh = pd.DataFrame(y_3)

y_4 = np.full(data_4.shape[0], 2)
y_ssh1 = pd.DataFrame(y_4)

y_5 = np.full(data_5.shape[0], 2)
y_ssh2 = pd.DataFrame(y_5)

y_6 = np.full(data_6.shape[0], 2)
y_ssh3 = pd.DataFrame(y_6)

y_7 = np.full(data_7.shape[0], 2)
y_ssh4 = pd.DataFrame(y_7)


# merging the original dataframe
y = pd.concat([y_benign, y_bf, y_ssh,y_ssh1,y_ssh2,y_ssh3,y_ssh4], sort=True).reset_index(drop=True)

# %%
x = clean_data.iloc[:,:-1]
y =u

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x = scaler.fit_transform(x)

# %%
from keras.utils.np_utils import to_categorical

y = to_categorical(y,num_classes=7)

# %%
train_prop = 0.8
indices = np.random.permutation(x.shape[0])
split_point = int(x.shape[0] * train_prop)

X_train, y_train = x[indices[:split_point]], y[indices[:split_point]]
X_test, y_test = x[indices[split_point:]], y[indices[split_point:]]

# %%
from keras.models import Sequential, Model
from keras.layers import LSTM, Dropout, Dense, Conv1D, BatchNormalization, MaxPooling1D, Flatten, Input, concatenate

# Define the first model
def create_cnn_model(input_shape):
    model = Sequential()
    model.add(Conv1D(filters=64, kernel_size=6, activation='relu', padding='same', input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=(3), strides=2, padding='same'))
    model.add(Conv1D(filters=64, kernel_size=6, activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=(3), strides=2, padding='same'))
    model.add(Conv1D(filters=64, kernel_size=6, activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=(3), strides=2, padding='same'))
    model.add(Flatten())
    model.add(Dense(64, activation='relu'))
    model.add(Dense(64, activation='relu'))
    return model

# Define the second model
def create_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(units=50, return_sequences=True, input_shape=input_shape))
    model.add(Dropout(0.2))
    model.add(LSTM(units=50, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(units=50, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(units=50, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(units=50))
    model.add(Dropout(0.2))
    model.add(Dense(units=1))
    return model

# Define input shape for the models
cnn_input_shape = (14, 1)
lstm_input_shape = (14, 1)

# Create the models
cnn_model = create_cnn_model(cnn_input_shape)
lstm_model = create_lstm_model(lstm_input_shape)

# Create a shared input layer
shared_input = Input(shape=cnn_input_shape)

# Connect the shared input to both models
cnn_output = cnn_model(shared_input)
lstm_output = lstm_model(shared_input)

# Concatenate the outputs from both models
merged = concatenate([cnn_output, lstm_output])

# Add more layers as needed for your specific task
merged = Dense(128, activation='relu')(merged)
merged = Dropout(0.2)(merged)
merged = Dense(7, activation='softmax')(merged)

# Create the final stacked model
stacked_model = Model(inputs=shared_input, outputs=merged)

# Compile the model
stacked_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the summary of the stacked model
stacked_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 14, 1)]      0           []
#
#  sequential_4 (Sequential)      (None, 64)           62912       ['input_3[0][0]']
#
#  sequential_5 (Sequential)      (None, 1)            91251       ['input_3[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 65)           0           ['sequential_4[0][0]',
#                                                                   'sequential_5[0][0]']
#
#  dense_13 (Dense)               (None, 128)          8448        ['concatenate_2[0][0]']
#
#  dropout_17 (Dropout)           (None, 128)          0           ['dense_13[0][0]']
#
#  dense_14 (Dense)               (None, 7)            903         ['dropout_17[0][0]']
#
# ==================================================================================================
# Total params: 163,514
# Trainable params: 163,130
# Non-trainable params: 384
# __________________________________________________________________________________________________

# %%
stacked_model.fit(X_train, y_train, epochs=50, batch_size=32,validation_split=0.2)
# Out:
# Epoch 1/50
# 10408/10408 [==============================] - 192s 16ms/step - loss: 0.0866 - accuracy: 0.9653 - val_loss: 0.2692 - val_accuracy: 0.8701
# Epoch 2/50
# 10408/10408 [==============================] - 166s 16ms/step - loss: 0.0490 - accuracy: 0.9810 - val_loss: 0.0482 - val_accuracy: 0.9831
# Epoch 3/50
# 10408/10408 [==============================] - 167s 16ms/step - loss: 0.0377 - accuracy: 0.9864 - val_loss: 0.0345 - val_accuracy: 0.9890
# Epoch 4/50
# 10408/10408 [==============================] - 164s 16ms/step - loss: 0.0324 - accuracy: 0.9885 - val_loss: 0.0304 - val_accuracy: 0.9900
# Epoch 5/50
# 10408/10408 [==============================] - 165s 16ms/step - loss: 0.0318 - accuracy: 0.9889 - val_loss: 0.0502 - val_accuracy: 0.9833
# Epoch 6/50
# 10408/10408 [==============================] - 163s 16ms/step - loss: 0.0287 - accuracy: 0.9899 - val_loss: 0.0625 - val_accuracy: 0.9823
# Epoch 7/50
# 10408/10408 [==============================] - 166s 16ms/step - loss: 0.0264 - accuracy: 0.9908 - val_loss: 0.0228 - val_accuracy: 0.9923
# Epoch 8/50
# 10408/10408 [==============================] - 167s 16ms/step - loss: 0.0253 - accuracy: 0.9913 - val_loss: 0.0210 - val_accuracy: 0.9927
# Epoch 9/50
# 10408/10408 [==============================] - 169s 16ms/step - loss: 0.0240 - accuracy: 0.9918 - val_loss: 0.0328 - val_accuracy: 0.9890
# Epoch 10/50
# 10408/10408 [==============================] - 169s 16ms/step - loss: 0.0233 - accuracy: 0.9919 - val_loss: 0.0209 - val_accuracy: 0.9925
# Epoch 11/50
# 10408/10408 [==============================] - 170s 16ms/step - loss: 0.0221 - accuracy: 0.9923 - val_loss: 0.0262 - val_accuracy: 0.9911
# Epoch 12/50
# 10408/10408 [==============================] - 169s 16ms/step - loss: 0.0251 - accuracy: 0.9913 - val_loss: 0.0310 - val_accuracy: 0.9902
# Epoch 13/50
# 10408/10408 [==============================] - 171s 16ms/step - loss: 0.0217 - accuracy: 0.9924 - val_loss: 0.0361 - val_accuracy: 0.9916
# Epoch 14/50
# 10408/10408 [==============================] - 170s 16ms/step - loss: 0.0216 - accuracy: 0.9926 - val_loss: 0.0224 - val_accuracy: 0.9922
# Epoch 15/50
# 10408/10408 [==============================] - 168s 16ms/step - loss: 0.0209 - accuracy: 0.9927 - val_loss: 0.0214 - val_accuracy: 0.9925
# Epoch 16/50
# 10408/10408 [==============================] - 168s 16ms/step - loss: 0.0209 - accuracy: 0.9928 - val_loss: 0.0260 - val_accuracy: 0.9921
# Epoch 17/50
# 10408/10408 [==============================] - 167s 16ms/step - loss: 0.0208 - accuracy: 0.9929 - val_loss: 0.0424 - val_accuracy: 0.9899
# Epoch 18/50
# 10408/10408 [==============================] - 169s 16ms/step - loss: 0.0206 - accuracy: 0.9929 - val_loss: 0.0227 - val_accuracy: 0.9934
# Epoch 19/50
# 10408/10408 [==============================] - 170s 16ms/step - loss: 0.0209 - accuracy: 0.9929 - val_loss: 0.0208 - val_accuracy: 0.9940
# Epoch 20/50
# 10408/10408 [==============================] - 170s 16ms/step - loss: 0.0200 - accuracy: 0.9932 - val_loss: 0.0205 - val_accuracy: 0.9926
# Epoch 21/50
# 10408/10408 [==============================] - 169s 16ms/step - loss: 0.0190 - accuracy: 0.9933 - val_loss: 0.0214 - val_accuracy: 0.9935
# Epoch 22/50
# 10408/10408 [==============================] - 171s 16ms/step - loss: 0.0187 - accuracy: 0.9933 - val_loss: 0.0187 - val_accuracy: 0.9943
# Epoch 23/50
# 10408/10408 [==============================] - 170s 16ms/step - loss: 0.0189 - accuracy: 0.9933 - val_loss: 0.0218 - val_accuracy: 0.9919
# Epoch 24/50
# 10408/10408 [==============================] - 168s 16ms/step - loss: 0.0194 - accuracy: 0.9932 - val_loss: 0.0190 - val_accuracy: 0.9941
# Epoch 25/50
# 10408/10408 [==============================] - 169s 16ms/step - loss: 0.0189 - accuracy: 0.9933 - val_loss: 0.0183 - val_accuracy: 0.9935
# Epoch 26/50
# 10408/10408 [==============================] - 171s 16ms/step - loss: 0.0191 - accuracy: 0.9936 - val_loss: 0.0613 - val_accuracy: 0.9875
# Epoch 27/50
# 10408/10408 [==============================] - 173s 17ms/step - loss: 0.0195 - accuracy: 0.9935 - val_loss: 0.0748 - val_accuracy: 0.9766
# Epoch 28/50
# 10408/10408 [==============================] - 173s 17ms/step - loss: 0.0186 - accuracy: 0.9935 - val_loss: 0.0234 - val_accuracy: 0.9939
# Epoch 29/50
# 10408/10408 [==============================] - 171s 16ms/step - loss: 0.0186 - accuracy: 0.9936 - val_loss: 0.0203 - val_accuracy: 0.9926
# Epoch 30/50
# 10408/10408 [==============================] - 172s 17ms/step - loss: 0.0188 - accuracy: 0.9934 - val_loss: 0.0179 - val_accuracy: 0.9935
# Epoch 31/50
# 10408/10408 [==============================] - 170s 16ms/step - loss: 0.0183 - accuracy: 0.9937 - val_loss: 0.0177 - val_accuracy: 0.9940
# Epoch 32/50
# 10408/10408 [==============================] - 171s 16ms/step - loss: 0.0179 - accuracy: 0.9933 - val_loss: 0.0255 - val_accuracy: 0.9927
# Epoch 33/50
# 10408/10408 [==============================] - 171s 16ms/step - loss: 0.0185 - accuracy: 0.9938 - val_loss: 0.0190 - val_accuracy: 0.9940
# Epoch 34/50
# 10408/10408 [==============================] - 173s 17ms/step - loss: 0.0181 - accuracy: 0.9936 - val_loss: 0.0233 - val_accuracy: 0.9926
# Epoch 35/50
# 10408/10408 [==============================] - 173s 17ms/step - loss: 0.0198 - accuracy: 0.9935 - val_loss: 0.0288 - val_accuracy: 0.9928
# Epoch 36/50
# 10408/10408 [==============================] - 172s 16ms/step - loss: 0.0187 - accuracy: 0.9938 - val_loss: 0.0181 - val_accuracy: 0.9941
# Epoch 37/50
# 10408/10408 [==============================] - 172s 17ms/step - loss: 0.0178 - accuracy: 0.9938 - val_loss: 0.0170 - val_accuracy: 0.9945
# Epoch 38/50
# 10408/10408 [==============================] - 179s 17ms/step - loss: 0.0182 - accuracy: 0.9937 - val_loss: 0.0217 - val_accuracy: 0.9927
# Epoch 39/50
# 10408/10408 [==============================] - 169s 16ms/step - loss: 0.0175 - accuracy: 0.9937 - val_loss: 0.0315 - val_accuracy: 0.9938
# Epoch 40/50
# 10408/10408 [==============================] - 168s 16ms/step - loss: 0.0181 - accuracy: 0.9939 - val_loss: 0.0208 - val_accuracy: 0.9921
# Epoch 41/50
# 10408/10408 [==============================] - 168s 16ms/step - loss: 0.0172 - accuracy: 0.9940 - val_loss: 0.0197 - val_accuracy: 0.9934
# Epoch 42/50
# 10408/10408 [==============================] - 168s 16ms/step - loss: 0.0170 - accuracy: 0.9942 - val_loss: 0.0627 - val_accuracy: 0.9905
# Epoch 43/50
# 10408/10408 [==============================] - 169s 16ms/step - loss: 0.0176 - accuracy: 0.9942 - val_loss: 0.0234 - val_accuracy: 0.9938
# Epoch 44/50
# 10408/10408 [==============================] - 168s 16ms/step - loss: 0.0172 - accuracy: 0.9939 - val_loss: 0.0217 - val_accuracy: 0.9936
# Epoch 45/50
# 10408/10408 [==============================] - 169s 16ms/step - loss: 0.0171 - accuracy: 0.9942 - val_loss: 0.0250 - val_accuracy: 0.9915
# Epoch 46/50
# 10408/10408 [==============================] - 168s 16ms/step - loss: 0.0162 - accuracy: 0.9941 - val_loss: 0.0534 - val_accuracy: 0.9853
# Epoch 47/50
# 10408/10408 [==============================] - 167s 16ms/step - loss: 0.0185 - accuracy: 0.9940 - val_loss: 0.0216 - val_accuracy: 0.9944
# Epoch 48/50
# 10408/10408 [==============================] - 166s 16ms/step - loss: 0.0170 - accuracy: 0.9940 - val_loss: 0.0211 - val_accuracy: 0.9943
# Epoch 49/50
# 10408/10408 [==============================] - 169s 16ms/step - loss: 0.0195 - accuracy: 0.9934 - val_loss: 0.0173 - val_accuracy: 0.9940
# Epoch 50/50
# 10408/10408 [==============================] - 177s 17ms/step - loss: 0.0163 - accuracy: 0.9943 - val_loss: 0.0258 - val_accuracy: 0.9945

# %%
r = stacked_model.predict(X_test)
# Out:
# 3253/3253 [==============================] - 16s 5ms/step

# %%
r  = np.argmax(r, axis=1)
y_test_f = np.argmax(y_test, axis=1)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test_f, r, digits=5))
# Out:
#               precision    recall  f1-score   support
#
#            0    0.91837   0.67164   0.77586        67
#            1    0.99705   0.96296   0.97971       351
#            2    0.99819   0.98939   0.99377     12820
#            3    0.00000   0.00000   0.00000         2
#            4    0.99545   0.99837   0.99691     87049
#            5    0.96893   0.95951   0.96420      3705
#            6    1.00000   0.07500   0.13953        80
#
#     accuracy                        0.99482    104074
#    macro avg    0.83971   0.66527   0.69286    104074
# weighted avg    0.99479   0.99482   0.99448    104074
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.metrics import confusion_matrix

# assume y_true and y_pred are the true and predicted labels, respectively
cm = confusion_matrix(y_test_f, r)

# calculate the number of false alarms
num_false_alarms = 0
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        if i != j:
            num_false_alarms += cm[i][j]

# calculate the total number of predictions
num_predictions = sum(sum(cm))

# calculate the false alarm rate
false_alarm_rate = num_false_alarms / num_predictions

print("False alarm rate: {:.5f}".format(false_alarm_rate))
# Out:
# False alarm rate: 0.00518
