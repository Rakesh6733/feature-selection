# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
tue = pd.read_csv("/content/drive/MyDrive/Untitled folder/mon.csv")

# %%
tue.iloc[:,-1].value_counts()
# Out:
# BENIGN    502983
# Name:  Label, dtype: int64

# %%
tue.duplicated().sum()
# Out:
# 0

# %%
tue.shape
# Out:
# (445909, 79)

# %%
tue.drop_duplicates(inplace=True)

# %%
tue.duplicated().sum()
# Out:
# 0

# %%
tue.shape
# Out:
# (421844, 79)

# %%
tue.to_csv("wed.csv", index=False)

# %%
import random

random.seed(12356)
print(random.random())
print(random.random())
print(random.random())
# Out:
# 0.7450675979593829
# 0.09540942624631088
# 0.8403974462720614
