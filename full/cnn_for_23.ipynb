# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df1 = pd.read_csv("/content/drive/MyDrive/data.csv")

# %%
df1
# Out:
#         Unnamed: 0   Destination Port   Flow Duration   Total Fwd Packets  \
# 0               15                 88             822                   7
# 1               27                 88            1112                   9
# 2               31              49671        26361049                  21
# 3               41                389               1                   2
# 4               56                 88            1122                  10
# ...            ...                ...             ...                 ...
# 520710      692350                 80        11502682                   8
# 520711      692358                 80        11500965                   7
# 520712      692395                 80        11501780                   7
# 520713      692591                 80        11514480                   8
# 520714      692681                 80        11509095                   8
#
#          Total Backward Packets  Total Length of Fwd Packets  \
# 0                             4                          458
# 1                             7                         3134
# 2                            14                         3720
# 3                             0                            7
# 4                             6                         3150
# ...                         ...                          ...
# 520710                        6                          495
# 520711                        5                          296
# 520712                        5                          375
# 520713                        6                          436
# 520714                        5                          369
#
#          Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                                356                     220
# 1                               3054                    1552
# 2                               2672                     936
# 3                                  0                       7
# 4                               3152                    1575
# ...                              ...                     ...
# 520710                         11632                     495
# 520711                         11632                     296
# 520712                         11632                     375
# 520713                         11632                     436
# 520714                         11632                     369
#
#          Fwd Packet Length Min   Fwd Packet Length Mean  ...  \
# 0                            0                65.428571  ...
# 1                            0               348.222222  ...
# 2                            0               177.142857  ...
# 3                            0                 3.500000  ...
# 4                            0               315.000000  ...
# ...                        ...                      ...  ...
# 520710                       0                61.875000  ...
# 520711                       0                42.285714  ...
# 520712                       0                53.571429  ...
# 520713                       0                54.500000  ...
# 520714                       0                46.125000  ...
#
#          min_seg_size_forward  Active Mean   Active Std   Active Max  \
# 0                          20          0.0          0.0            0
# 1                          20          0.0          0.0            0
# 2                          20          0.0          0.0            0
# 3                          32          0.0          0.0            0
# 4                          32          0.0          0.0            0
# ...                       ...          ...          ...          ...
# 520710                     32        740.0          0.0          740
# 520711                     32        870.0          0.0          870
# 520712                     32        880.0          0.0          880
# 520713                     32        897.0          0.0          897
# 520714                     32        914.0          0.0          914
#
#          Active Min  Idle Mean   Idle Std   Idle Max   Idle Min     Label
# 0                 0        0.0        0.0          0          0    Normal
# 1                 0        0.0        0.0          0          0    Normal
# 2                 0        0.0        0.0          0          0    Normal
# 3                 0        0.0        0.0          0          0    Normal
# 4                 0        0.0        0.0          0          0    Normal
# ...             ...        ...        ...        ...        ...       ...
# 520710          740  6500545.0        0.0    6500545    6500545  Dos/DdoS
# 520711          870  6498892.0        0.0    6498892    6498892  Dos/DdoS
# 520712          880  6499656.0        0.0    6499656    6499656  Dos/DdoS
# 520713          897  6509268.0        0.0    6509268    6509268  Dos/DdoS
# 520714          914  6504954.0        0.0    6504954    6504954  Dos/DdoS
#
# [520715 rows x 80 columns]

# %%
import numpy as np

# %%
df1.replace([np.inf, -np.inf], np.nan, inplace=True)
  
# Dropping all the rows with nan values
df1.dropna(inplace=True)
df1.isin([np.inf, -np.inf]).sum()
# Out:
# Unnamed: 0                 0
#  Destination Port          0
#  Flow Duration             0
#  Total Fwd Packets         0
#  Total Backward Packets    0
#                           ..
# Idle Mean                  0
#  Idle Std                  0
#  Idle Max                  0
#  Idle Min                  0
#  Label                     0
# Length: 80, dtype: int64

# %%
network_data=df1

# %%
clean_data = network_data.dropna()

# %%
clean_data.reset_index(inplace=True, drop=True)

# %%
from sklearn.preprocessing import LabelEncoder
l = LabelEncoder()
u = l.fit_transform(clean_data.iloc[:,-1])

# %%
import numpy as np
data_1 = u[u == 0]
data_2 = u[u == 1]
data_3 = u[u == 2]
data_4 = u[u == 3]
data_5 = u[u == 4]
data_6 = u[u == 5]
data_7 = u[u == 6]


# make benign feature
y_1 = np.zeros(data_1.shape[0])
y_benign = pd.DataFrame(y_1)

# make bruteforce feature
y_2 = np.ones(data_2.shape[0])
y_bf = pd.DataFrame(y_2)

# make bruteforceSSH feature
y_3 = np.full(data_3.shape[0], 2)
y_ssh = pd.DataFrame(y_3)

y_4 = np.full(data_4.shape[0], 2)
y_ssh1 = pd.DataFrame(y_4)

y_5 = np.full(data_5.shape[0], 2)
y_ssh2 = pd.DataFrame(y_5)

y_6 = np.full(data_6.shape[0], 2)
y_ssh3 = pd.DataFrame(y_6)

y_7 = np.full(data_7.shape[0], 2)
y_ssh4 = pd.DataFrame(y_7)


# merging the original dataframe
y = pd.concat([y_benign, y_bf, y_ssh,y_ssh1,y_ssh2,y_ssh3,y_ssh4], sort=True).reset_index(drop=True)

# %%
y = u/6.0
x = clean_data.iloc[:,:-1]

# %%
from keras.utils.np_utils import to_categorical

y = to_categorical(y,num_classes=7)

# %%
clean_data.reset_index(inplace=True, drop=True)

# %%
from sklearn.preprocessing import LabelEncoder
l = LabelEncoder()
u = l.fit_transform(clean_data.iloc[:,-1])

# %%
import numpy as np
data_1 = u[u == 0]
data_2 = u[u == 1]
data_3 = u[u == 2]
data_4 = u[u == 3]
data_5 = u[u == 4]
data_6 = u[u == 5]
data_7 = u[u == 6]


# make benign feature
y_1 = np.zeros(data_1.shape[0])
y_benign = pd.DataFrame(y_1)

# make bruteforce feature
y_2 = np.ones(data_2.shape[0])
y_bf = pd.DataFrame(y_2)

# make bruteforceSSH feature
y_3 = np.full(data_3.shape[0], 2)
y_ssh = pd.DataFrame(y_3)

y_4 = np.full(data_4.shape[0], 2)
y_ssh1 = pd.DataFrame(y_4)

y_5 = np.full(data_5.shape[0], 2)
y_ssh2 = pd.DataFrame(y_5)

y_6 = np.full(data_6.shape[0], 2)
y_ssh3 = pd.DataFrame(y_6)

y_7 = np.full(data_7.shape[0], 2)
y_ssh4 = pd.DataFrame(y_7)


# merging the original dataframe
y = pd.concat([y_benign, y_bf, y_ssh,y_ssh1,y_ssh2,y_ssh3,y_ssh4], sort=True).reset_index(drop=True)

# %%
x = clean_data.iloc[:,:-1]
y =u

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x = scaler.fit_transform(x)

# %%
x.shape
# Out:
# (520369, 79)

# %%
from keras.utils.np_utils import to_categorical

y = to_categorical(y,num_classes=7)

# %%
from keras.layers import Conv2D, Conv1D, MaxPooling2D, MaxPooling1D, Flatten, BatchNormalization, Dense
from keras.models import Sequential

# %%
def model():
    model = Sequential()
    model.add(Conv1D(filters=64, kernel_size=6, activation='relu', 
                    padding='same', input_shape=(79, 1)))
    model.add(BatchNormalization())
    
    # adding a pooling layer
    model.add(MaxPooling1D(pool_size=(3), strides=2, padding='same'))
    
    model.add(Conv1D(filters=64, kernel_size=6, activation='relu', 
                    padding='same', input_shape=(79, 1)))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=(3), strides=2, padding='same'))
    
    model.add(Conv1D(filters=64, kernel_size=6, activation='relu', 
                    padding='same', input_shape=(72, 1)))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=(3), strides=2, padding='same'))
    
    model.add(Flatten())
    model.add(Dense(64, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(7, activation='softmax'))
    
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
from sklearn.model_selection import train_test_split
x_train_f,x_test_f, y_train_f, y_test_f= train_test_split(x,y, test_size=0.3, random_state=12)

# %%
train_prop = 0.8
indices = np.random.permutation(x.shape[0])
split_point = int(x.shape[0] * train_prop)

X_train, y_train = x[indices[:split_point]], y[indices[:split_point]]
X_test, y_test = x[indices[split_point:]], y[indices[split_point:]]

# %%
t = np.argmax(y_train, axis=1)
r = pd.DataFrame(t)
r.value_counts()
# Out:
# 4    347824
# 2     51687
# 5     14661
# 1      1467
# 6       340
# 0       311
# 3         5
# dtype: int64

# %%
mo = model()
his = mo.fit(X_train, y_train, epochs=50, batch_size=32,validation_split=0.2)
# Out:
# Epoch 1/50
# 10408/10408 [==============================] - 74s 7ms/step - loss: 0.0636 - accuracy: 0.9739 - val_loss: 0.0589 - val_accuracy: 0.9710
# Epoch 2/50
# 10408/10408 [==============================] - 70s 7ms/step - loss: 0.0329 - accuracy: 0.9876 - val_loss: 0.0281 - val_accuracy: 0.9886
# Epoch 3/50
# 10408/10408 [==============================] - 69s 7ms/step - loss: 0.0252 - accuracy: 0.9907 - val_loss: 0.0239 - val_accuracy: 0.9912
# Epoch 4/50
# 10408/10408 [==============================] - 70s 7ms/step - loss: 0.0219 - accuracy: 0.9917 - val_loss: 0.0202 - val_accuracy: 0.9925
# Epoch 5/50
# 10408/10408 [==============================] - 70s 7ms/step - loss: 0.0200 - accuracy: 0.9926 - val_loss: 0.0212 - val_accuracy: 0.9921
# Epoch 6/50
# 10408/10408 [==============================] - 71s 7ms/step - loss: 0.0186 - accuracy: 0.9929 - val_loss: 0.0235 - val_accuracy: 0.9899
# Epoch 7/50
# 10408/10408 [==============================] - 70s 7ms/step - loss: 0.0180 - accuracy: 0.9930 - val_loss: 0.0187 - val_accuracy: 0.9936
# Epoch 8/50
# 10408/10408 [==============================] - 69s 7ms/step - loss: 0.0173 - accuracy: 0.9933 - val_loss: 0.0165 - val_accuracy: 0.9930
# Epoch 9/50
# 10408/10408 [==============================] - 69s 7ms/step - loss: 0.0171 - accuracy: 0.9935 - val_loss: 0.0170 - val_accuracy: 0.9934
# Epoch 10/50
# 10408/10408 [==============================] - 69s 7ms/step - loss: 0.0163 - accuracy: 0.9936 - val_loss: 0.0172 - val_accuracy: 0.9934
# Epoch 11/50
# 10408/10408 [==============================] - 69s 7ms/step - loss: 0.0163 - accuracy: 0.9937 - val_loss: 0.0153 - val_accuracy: 0.9939
# Epoch 12/50
# 10408/10408 [==============================] - 69s 7ms/step - loss: 0.0152 - accuracy: 0.9939 - val_loss: 0.0229 - val_accuracy: 0.9903
# Epoch 13/50
# 10408/10408 [==============================] - 69s 7ms/step - loss: 0.0152 - accuracy: 0.9939 - val_loss: 0.0176 - val_accuracy: 0.9937
# Epoch 14/50
# 10408/10408 [==============================] - 70s 7ms/step - loss: 0.0150 - accuracy: 0.9941 - val_loss: 0.0134 - val_accuracy: 0.9940
# Epoch 15/50
# 10408/10408 [==============================] - 70s 7ms/step - loss: 0.0146 - accuracy: 0.9941 - val_loss: 0.0183 - val_accuracy: 0.9929
# Epoch 16/50
# 10408/10408 [==============================] - 69s 7ms/step - loss: 0.0143 - accuracy: 0.9941 - val_loss: 0.0157 - val_accuracy: 0.9939
# Epoch 17/50
# 10408/10408 [==============================] - 69s 7ms/step - loss: 0.0148 - accuracy: 0.9943 - val_loss: 0.0149 - val_accuracy: 0.9942
# Epoch 18/50
# 10408/10408 [==============================] - 69s 7ms/step - loss: 0.0140 - accuracy: 0.9943 - val_loss: 0.0165 - val_accuracy: 0.9934
# Epoch 19/50
# 10408/10408 [==============================] - 69s 7ms/step - loss: 0.0139 - accuracy: 0.9944 - val_loss: 0.0167 - val_accuracy: 0.9944
# Epoch 20/50
# 10408/10408 [==============================] - 69s 7ms/step - loss: 0.0138 - accuracy: 0.9944 - val_loss: 0.0261 - val_accuracy: 0.9907
# Epoch 21/50
# 10408/10408 [==============================] - 69s 7ms/step - loss: 0.0134 - accuracy: 0.9946 - val_loss: 0.0130 - val_accuracy: 0.9953
# Epoch 22/50
# 10408/10408 [==============================] - 69s 7ms/step - loss: 0.0189 - accuracy: 0.9932 - val_loss: 0.0166 - val_accuracy: 0.9927
# Epoch 23/50
# 10408/10408 [==============================] - 69s 7ms/step - loss: 0.0145 - accuracy: 0.9938 - val_loss: 0.0262 - val_accuracy: 0.9908
# Epoch 24/50
# 10408/10408 [==============================] - 69s 7ms/step - loss: 0.0136 - accuracy: 0.9945 - val_loss: 0.0161 - val_accuracy: 0.9940
# Epoch 25/50
# 10408/10408 [==============================] - 69s 7ms/step - loss: 0.0134 - accuracy: 0.9947 - val_loss: 0.0117 - val_accuracy: 0.9952
# Epoch 26/50
# 10408/10408 [==============================] - 69s 7ms/step - loss: 0.0131 - accuracy: 0.9947 - val_loss: 0.0210 - val_accuracy: 0.9916
# Epoch 27/50
# 10408/10408 [==============================] - 69s 7ms/step - loss: 0.0129 - accuracy: 0.9949 - val_loss: 0.0223 - val_accuracy: 0.9918
# Epoch 28/50
# 10408/10408 [==============================] - 69s 7ms/step - loss: 0.0134 - accuracy: 0.9949 - val_loss: 0.0160 - val_accuracy: 0.9941
# Epoch 29/50
# 10408/10408 [==============================] - 69s 7ms/step - loss: 0.0133 - accuracy: 0.9949 - val_loss: 0.0233 - val_accuracy: 0.9931
# Epoch 30/50
# 10408/10408 [==============================] - 69s 7ms/step - loss: 0.0125 - accuracy: 0.9950 - val_loss: 0.0151 - val_accuracy: 0.9940
# Epoch 31/50
# 10408/10408 [==============================] - 69s 7ms/step - loss: 0.0126 - accuracy: 0.9949 - val_loss: 0.0137 - val_accuracy: 0.9951
# Epoch 32/50
# 10408/10408 [==============================] - 68s 7ms/step - loss: 0.0122 - accuracy: 0.9952 - val_loss: 0.0119 - val_accuracy: 0.9955
# Epoch 33/50
# 10408/10408 [==============================] - 68s 7ms/step - loss: 0.0133 - accuracy: 0.9950 - val_loss: 0.0127 - val_accuracy: 0.9952
# Epoch 34/50
# 10408/10408 [==============================] - 68s 7ms/step - loss: 0.0132 - accuracy: 0.9950 - val_loss: 0.0256 - val_accuracy: 0.9907
# Epoch 35/50
# 10408/10408 [==============================] - 68s 7ms/step - loss: 0.0127 - accuracy: 0.9951 - val_loss: 0.0124 - val_accuracy: 0.9954
# Epoch 36/50
# 10408/10408 [==============================] - 68s 7ms/step - loss: 0.0126 - accuracy: 0.9951 - val_loss: 0.0127 - val_accuracy: 0.9951
# Epoch 37/50
# 10408/10408 [==============================] - 69s 7ms/step - loss: 0.0128 - accuracy: 0.9952 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 38/50
# 10408/10408 [==============================] - 68s 7ms/step - loss: 0.0122 - accuracy: 0.9953 - val_loss: 0.0148 - val_accuracy: 0.9946
# Epoch 39/50
# 10408/10408 [==============================] - 68s 7ms/step - loss: 0.0123 - accuracy: 0.9954 - val_loss: 0.0138 - val_accuracy: 0.9957
# Epoch 40/50
# 10408/10408 [==============================] - 68s 7ms/step - loss: 0.0126 - accuracy: 0.9952 - val_loss: 0.0279 - val_accuracy: 0.9861
# Epoch 41/50
# 10408/10408 [==============================] - 68s 7ms/step - loss: 0.0128 - accuracy: 0.9953 - val_loss: 0.0151 - val_accuracy: 0.9950
# Epoch 42/50
# 10408/10408 [==============================] - 68s 7ms/step - loss: 0.0122 - accuracy: 0.9952 - val_loss: 0.0249 - val_accuracy: 0.9945
# Epoch 43/50
# 10408/10408 [==============================] - 68s 7ms/step - loss: 0.0135 - accuracy: 0.9955 - val_loss: 0.0280 - val_accuracy: 0.9903
# Epoch 44/50
# 10408/10408 [==============================] - 68s 7ms/step - loss: 0.0125 - accuracy: 0.9953 - val_loss: 0.0180 - val_accuracy: 0.9951
# Epoch 45/50
# 10408/10408 [==============================] - 68s 7ms/step - loss: 0.0131 - accuracy: 0.9955 - val_loss: 0.0143 - val_accuracy: 0.9951
# Epoch 46/50
# 10408/10408 [==============================] - 68s 7ms/step - loss: 0.0123 - accuracy: 0.9953 - val_loss: 0.0135 - val_accuracy: 0.9960
# Epoch 47/50
# 10408/10408 [==============================] - 73s 7ms/step - loss: 0.0143 - accuracy: 0.9951 - val_loss: 0.0188 - val_accuracy: 0.9933
# Epoch 48/50
# 10408/10408 [==============================] - 68s 7ms/step - loss: 0.0130 - accuracy: 0.9953 - val_loss: 0.0146 - val_accuracy: 0.9949
# Epoch 49/50
# 10408/10408 [==============================] - 68s 7ms/step - loss: 0.0136 - accuracy: 0.9952 - val_loss: 0.0175 - val_accuracy: 0.9948
# Epoch 50/50
# 10408/10408 [==============================] - 69s 7ms/step - loss: 0.0115 - accuracy: 0.9956 - val_loss: 0.0122 - val_accuracy: 0.9958

# %%
r = mo.predict(X_test)
# Out:
# 3253/3253 [==============================] - 6s 2ms/step

# %%
r  = np.argmax(r, axis=1)
y_test_f = np.argmax(y_test, axis=1)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test_f, r, digits=5))
# Out:
#               precision    recall  f1-score   support
#
#            0    0.98077   0.66234   0.79070        77
#            1    0.96814   0.99496   0.98137       397
#            2    0.99597   0.99558   0.99577     12899
#            3    0.00000   0.00000   0.00000         2
#            4    0.99789   0.99677   0.99733     86922
#            5    0.94198   0.97722   0.95928      3688
#            6    1.00000   0.77528   0.87342        89
#
#     accuracy                        0.99546    104074
#    macro avg    0.84068   0.77174   0.79969    104074
# weighted avg    0.99553   0.99546   0.99545    104074

# %%
from sklearn.metrics import confusion_matrix

# assume y_true and y_pred are the true and predicted labels, respectively
cm = confusion_matrix(y_test_f, r)

# calculate the number of false alarms
num_false_alarms = 0
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        if i != j:
            num_false_alarms += cm[i][j]

# calculate the total number of predictions
num_predictions = sum(sum(cm))

# calculate the false alarm rate
false_alarm_rate = num_false_alarms / num_predictions

print("False alarm rate: {:.4f}".format(false_alarm_rate))
# Out:
# False alarm rate: 0.0045

# %%
from keras.models import Sequential
from keras.layers import LSTM,Dense,Dropout

# %%
model = Sequential()
model.add(LSTM(units=50,return_sequences=True,input_shape=(79, 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=7))

# %%
model.compile(optimizer="adam",loss="mean_squared_error",metrics=['accuracy'])

# %%
his = model.fit(X_train, y_train, epochs=50, batch_size=32,validation_split=0.2)
# Out:
# Epoch 1/50
# 10408/10408 [==============================] - 191s 17ms/step - loss: 0.0163 - accuracy: 0.9325 - val_loss: 0.0104 - val_accuracy: 0.9528
# Epoch 2/50
# 10408/10408 [==============================] - 181s 17ms/step - loss: 0.0104 - accuracy: 0.9518 - val_loss: 0.0119 - val_accuracy: 0.9363
# Epoch 3/50
# 10408/10408 [==============================] - 179s 17ms/step - loss: 0.0091 - accuracy: 0.9574 - val_loss: 0.0067 - val_accuracy: 0.9675
# Epoch 4/50
# 10408/10408 [==============================] - 180s 17ms/step - loss: 0.0078 - accuracy: 0.9636 - val_loss: 0.0067 - val_accuracy: 0.9691
# Epoch 5/50
# 10408/10408 [==============================] - 181s 17ms/step - loss: 0.0073 - accuracy: 0.9671 - val_loss: 0.0059 - val_accuracy: 0.9724
# Epoch 6/50
# 10408/10408 [==============================] - 183s 18ms/step - loss: 0.0066 - accuracy: 0.9708 - val_loss: 0.0058 - val_accuracy: 0.9738
# 10408/10408 [==============================] - 181s 17ms/step - loss: 0.0026 - accuracy: 0.9898 - val_loss: 0.0021 - val_accuracy: 0.9902
# Epoch 44/50
# 10408/10408 [==============================] - 181s 17ms/step - loss: 0.0025 - accuracy: 0.9901 - val_loss: 0.0019 - val_accuracy: 0.9908
# Epoch 45/50
# 10408/10408 [==============================] - 181s 17ms/step - loss: 0.0025 - accuracy: 0.9905 - val_loss: 0.0018 - val_accuracy: 0.9907
# Epoch 46/50
# 10408/10408 [==============================] - 181s 17ms/step - loss: 0.0025 - accuracy: 0.9903 - val_loss: 0.0018 - val_accuracy: 0.9914
# Epoch 47/50
# 10408/10408 [==============================] - 181s 17ms/step - loss: 0.0024 - accuracy: 0.9907 - val_loss: 0.0018 - val_accuracy: 0.9914
# Epoch 48/50
# 10408/10408 [==============================] - 180s 17ms/step - loss: 0.0024 - accuracy: 0.9908 - val_loss: 0.0021 - val_accuracy: 0.9902
# Epoch 49/50
# 10408/10408 [==============================] - 181s 17ms/step - loss: 0.0024 - accuracy: 0.9909 - val_loss: 0.0019 - val_accuracy: 0.9901
# Epoch 50/50
# 10408/10408 [==============================] - 182s 17ms/step - loss: 0.0023 - accuracy: 0.9909 - val_loss: 0.0018 - val_accuracy: 0.9917

# %%
r= model.predict(X_test)
# Out:
# 3253/3253 [==============================] - 22s 6ms/step

# %%
r  = np.argmax(r, axis=1)
y_test_f = np.argmax(y_test, axis=1)

# %%
print(classification_report(y_test_f, r, digits=5))
# Out:
#               precision    recall  f1-score   support
#
#            0    0.96078   0.63636   0.76562        77
#            1    0.91607   0.96222   0.93857       397
#            2    0.98985   0.98287   0.98635     12899
#            3    0.00000   0.00000   0.00000         2
#            4    0.99283   0.99703   0.99493     86922
#            5    0.96807   0.92082   0.94386      3688
#            6    0.00000   0.00000   0.00000        89
#
#     accuracy                        0.99130    104074
#    macro avg    0.68966   0.64276   0.66133    104074
# weighted avg    0.99040   0.99130   0.99080    104074
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
r  = np.argmax(r, axis=1)
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# <ipython-input-48-50cab12b63f8> in <cell line: 1>()
# ----> 1 r  = np.argmax(r, axis=1)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in argmax(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py in argmax(a, axis, out, keepdims)
#    1214     """
#    1215     kwds = {'keepdims': keepdims} if keepdims is not np._NoValue else {}
# -> 1216     return _wrapfunc(a, 'argmax', axis=axis, out=out, **kwds)
#    1217
#    1218
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      55
#      56     try:
# ---> 57         return bound(*args, **kwds)
#      58     except TypeError:
#      59         # A TypeError occurs if the object does have such a method in its
#
# AxisError: axis 1 is out of bounds for array of dimension 1

# %%
from sklearn.metrics import confusion_matrix

# assume y_true and y_pred are the true and predicted labels, respectively
cm = confusion_matrix(y_test_f, r)

# calculate the number of false alarm

num_false_alarms = 0
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        if i != j:
            num_false_alarms += cm[i][j]

# calculate the total number of predictions
num_predictions = sum(sum(cm))

# calculate the false alarm rate
false_alarm_rate = num_false_alarms / num_predictions

print("False alarm rate: {:.4f}".format(false_alarm_rate))
# Out:
# False alarm rate: 0.0087
